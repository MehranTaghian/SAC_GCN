#         -5.485196 ,  -6.5366783,  -5.79448  ,  -4.2617817,  -7.2557955,
#         -6.321153 ,  -3.325271 ,  -6.441623 ,  -5.7547965,  -6.640242 ,
#         -5.1051745,  -5.038179 ,  -5.4136896,  -6.9333987,  -5.2088857,
#         -3.6120183,  -5.1370687,  -7.021662 ,  -4.1646132,  -5.9911094,
#         -6.141653 ,  -6.909584 ,  -5.4152756,  -7.5028367,  -4.45926  ,
#         -5.3433824,  -7.7817006,  -6.6768413,  -5.06275  ,  -5.207927 ,
#         -7.843577 ,  -8.497977 ,  -4.61571  ,  -5.873631 ,  -6.8858247,
#         -5.953564 ,  -5.6562223,  -3.5354536,  -3.4169047,  -3.4517741,
#         -5.2439175,  -3.7456996,  -3.8757856,  -6.626562 ,  -6.788242 ,
#         -5.118716 ,  -3.8452108,  -4.8738384,  -6.3053265,  -4.7010083,
#         -5.207916 ,  -2.4596715,  -5.533903 ,  -4.93243  ,  -4.697527 ,
#         -4.601151 ,  -5.3230634,  -6.247883 ,  -4.4541116,  -5.275185 ,
#         -2.4402046,  -5.213079 ,  -5.083878 ,  -3.6369655,  -4.4380283,
#         -3.3584497,  -3.2567105,  -3.3019738,  -5.504883 ,  -3.9100113,
#         -3.8507278,  -4.479539 ,  -3.8099093,  -3.76995  ,  -2.8313465,
#         -3.0870504,  -6.641164 ,  -6.2740884,  -3.929156 ,  -2.6891654,
#         -2.6331568,  -3.587861 ,  -2.9824803,  -4.1299233,  -4.4300475,
#         -3.0079372,  -2.8150895,  -4.4892726,  -4.42229  ,  -3.1797762,
#         -4.551563 ,  -4.692893 ,  -5.293964 ,  -4.7672553,  -4.3123484,
#         -5.3299875,  -3.8724425,  -4.7876115,  -3.378522 ,  -4.154605 ,
#         -5.426281 ,  -4.964137 ,  -4.4712634,  -3.0038402,  -2.8047476,
#         -3.3516774,  -4.3662734,  -3.5978131,  -3.6301854,  -2.5971963,
#         -3.4765885,  -3.1798997,  -3.0838304,  -2.3726058,  -2.098436 ,
#         -4.888579 ,  -2.4742284,  -3.553127 ,  -3.1746511,  -3.2084436,
#         -3.7185276,  -2.9929776,  -3.7879584,  -3.1145828,  -4.142573 ],
#       dtype=float32)

# %%
plt.figure(figsize=[15,12])
seeds = os.listdir(path)
for s in seeds:
    data = load_object(f'{path}/{s}/eval.pkl')[:, 3]
    plt.plot(data, label=f'{s}')

plt.legend()
# Out:
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300

# %%
# data = load_object("/home/me/Documents/SAC_GCN/Data/cedar/Data/Walker2d-v2/graph/seed0/train.pkl")
bf = load_object("/home/taghianj/Documents/SAC_GCN/Data/buffer.pkl")


# os.path.getsize("/home/taghianj/Documents/SAC_GCN/Data/cedar/Walker2d-v2/graph/seed0/buffer.pkl")
# Out:
# 3129748029

# %%
import pickle, gzip
# file_path = "/home/taghianj/Documents/SAC_GCN/Data/cedar/Walker2d-v2/graph/seed0/buffer.pkl"
for seed in range(12):
    file_path = f"/home/taghianj/Documents/SAC_GCN/Data/cedar/Walker2d-v2/graph/seed{seed}/buffer.pkl"
    try:
        buffer = None
        with open(file_path, 'rb') as f:
            p = pickle.Unpickler(f)
            buffer = p.load()
    except EOFError:
        print(seed)
# Out:
# 0
# 5
# 6
# 9
# 10
# 11

# %%
import pickle, gzip
# file_path = "/home/taghianj/Documents/SAC_GCN/Data/cedar/Walker2d-v2/graph/seed0/buffer.pkl"
for seed in range(12):
    file_path = f"/home/taghianj/Documents/SAC_GCN/Data/beluga/HalfCheetah-v2/graph/seed{seed}/buffer.pkl"
    try:
        buffer = None
        with open(file_path, 'rb') as f:
            p = pickle.Unpickler(f)
            buffer = p.load()
    except EOFError:
        print(seed)
# Out:
# 5
# 6
# 7

# %%
from Graph_SAC.replay_memory import ReplayMemory

# %%
len(buffer)
# Out:
# 1000000

# %%
rm = ReplayMemory(1000000, 0)

# %%
# rm.load_buffer("/home/taghianj/Documents/SAC_GCN/Data/buffer.pkl")
rm.load_buffer("/home/taghianj/Documents/SAC_GCN/Data/cedar/Walker2d-v2/graph/seed0/buffer.pkl")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /tmp/ipykernel_60938/571774915.py in <module>
#       1 # rm.load_buffer("/home/taghianj/Documents/SAC_GCN/Data/buffer.pkl")
# ----> 2 rm.load_buffer("/home/taghianj/Documents/SAC_GCN/Data/cedar/Walker2d-v2/graph/seed0/buffer.pkl")
#
# ~/Documents/SAC_GCN/Graph_SAC/replay_memory.py in load_buffer(self, path)
#      43         with open(path, 'rb') as f:
#      44             p = pickle.Unpickler(f)
# ---> 45             self.buffer = p.load()
#      46             self.position = len(self.buffer) % self.capacity
#      47
#
# EOFError: Ran out of input

# %%
len(buffer)
# Out:
# 1000000

# %%
data = pd.read_csv("/home/mehran/Documents/SAC_GCN/Data/Hopper-v2/thigh_joint/seed2/eval.csv")

# %%
data
# Out:
#      num_episodes  num_steps  num_updates  eval_reward
# 0             9.0      194.0          0.0   121.254049
# 1            19.0      432.0        175.0   109.890246
# 2            29.0      641.0        384.0    68.919956
# 3            39.0      898.0        641.0    46.692771
# 4            49.0     1130.0        873.0    45.844892
# ..            ...        ...          ...          ...
# 995        9959.0  1776840.0    1776583.0   721.098825
# 996        9969.0  1778792.0    1778535.0   691.768661
# 997        9979.0  1780701.0    1780444.0   718.182107
# 998        9989.0  1782675.0    1782418.0   681.614950
# 999           0.0        0.0          0.0     0.000000
#
# [1000 rows x 4 columns]

# %%
from threading import Thread
import pickle, pickletools, gzip
import time

def save_object(obj, path):
    with gzip.open(path, "wb") as f:
        pickled = pickle.dumps(obj)
        optimized_pickle = pickletools.optimize(pickled)
        f.write(optimized_pickle)

def load_object(path):
    with gzip.open(path, 'rb') as f:
        p = pickle.Unpickler(f)
        obj = p.load()
    return obj

class Buffer:
    def __init__(self):
        self.thread = None
        self.obj = None
        
    def save_obj(self, path):
        if self.thread is not None:
            self.thread.join()
        self.thread = Thread(target=save_object, args=(self.obj.copy(), path))
        self.thread.start()

# %%
import numpy as np

a = np.arange(1000000).reshape([1000,1000])
bf = Buffer()
bf.obj = a
bf.save_obj('test.pkl')
# b = np.arange(10000).reshape([100, 100])
# bf.obj = b
# bf.save_obj('test.pkl')

# %%
c1 = load_object('test.pkl')

# %%
c2 = load_object('test2.pkl')

# %%
c1
# Out:
# array([[     0,      1,      2, ...,    997,    998,    999],
#        [  1000,   1001,   1002, ...,   1997,   1998,   1999],
#        [  2000,   2001,   2002, ...,   2997,   2998,   2999],
#        ...,
#        [997000, 997001, 997002, ..., 997997, 997998, 997999],
#        [998000, 998001, 998002, ..., 998997, 998998, 998999],
#        [999000, 999001, 999002, ..., 999997, 999998, 999999]])

# %%
c2
# Out:
# array([[   0,    1,    2, ...,   97,   98,   99],
#        [ 100,  101,  102, ...,  197,  198,  199],
#        [ 200,  201,  202, ...,  297,  298,  299],
#        ...,
#        [9700, 9701, 9702, ..., 9797, 9798, 9799],
#        [9800, 9801, 9802, ..., 9897, 9898, 9899],
#        [9900, 9901, 9902, ..., 9997, 9998, 9999]])
